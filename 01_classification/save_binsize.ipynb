# %%
import sys, os
import numpy as np
import pandas as pd

sys.path.append("../prepare")
from app_info import *

# %%
app_binsize_dd = {}
for app, app_dir in app2dir_dd.iteritems():
    print app, app_dir
    dir_files = os.listdir(app_dir)
    run_script = app_dir + '/run.sh'
    #sprint run_script

    with open(run_script) as fopen:
        context = fopen.readlines()
        
    for i, line in enumerate(context):
        if not "bin/bash" in line and len(line)>1 and line[0] == '.':
            #print "check currentline"
            #print line, len(line)
            appName_str = line.split()[0]
            if not "#" in appName_str:
                #print appName_str
                appName = appName_str.split('/')[-1]
                print appName
                
                app_url =  app_dir + '/' +appName
                app_size_in_bytes = os.path.getsize(app_url)
                print app_url, app_size_in_bytes
                
                app_binsize_dd[app] = app_size_in_bytes
        
    #print "======="
    # break
# Out:
# rodinia_b+tree ../apps/devid_rodinia/b+tree
# b+tree.out
# ../apps/devid_rodinia/b+tree/b+tree.out 90845
# cudasdk_threadFenceReduction ../apps/devid_cudasdk80/6_Advanced/threadFenceReduction
# threadFenceReduction
# ../apps/devid_cudasdk80/6_Advanced/threadFenceReduction/threadFenceReduction 1365373
# cudasdk_convolutionFFT2D ../apps/devid_cudasdk80/3_Imaging/convolutionFFT2D
# convolutionFFT2D
# ../apps/devid_cudasdk80/3_Imaging/convolutionFFT2D/convolutionFFT2D 720951
# shoc_lev1BFS ../apps/devid_shoc/src/cuda/level1/bfs
# BFS
# ../apps/devid_shoc/src/cuda/level1/bfs/BFS 2557405
# rodinia_lavaMD ../apps/devid_rodinia/lavaMD
# lavaMD
# ../apps/devid_rodinia/lavaMD/lavaMD 61578
# poly_gemm ../apps/devid_poly/CUDA/GEMM
# gemm.exe
# ../apps/devid_poly/CUDA/GEMM/gemm.exe 595675
# rodinia_hybridsort ../apps/devid_rodinia/hybridsort
# hybridsort
# ../apps/devid_rodinia/hybridsort/hybridsort 763228
# cudasdk_MCEstimatePiInlineQ ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiInlineQ
# MC_EstimatePiInlineQ
# ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiInlineQ/MC_EstimatePiInlineQ 1487860
# cudasdk_MCEstimatePiInlineP ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiInlineP
# MC_EstimatePiInlineP
# ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiInlineP/MC_EstimatePiInlineP 1630233
# cudasdk_shflscan ../apps/devid_cudasdk80/6_Advanced/shfl_scan
# shfl_scan
# ../apps/devid_cudasdk80/6_Advanced/shfl_scan/shfl_scan 670816
# rodinia_dwt2d ../apps/devid_rodinia/dwt2d
# dwt2d
# ../apps/devid_rodinia/dwt2d/dwt2d 1604815
# cudasdk_vectorAdd ../apps/devid_cudasdk80/0_Simple/vectorAdd
# vectorAdd
# ../apps/devid_cudasdk80/0_Simple/vectorAdd/vectorAdd 595510
# cudasdk_MCEstimatePiP ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiP
# MC_EstimatePiP
# ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiP/MC_EstimatePiP 654514
# cudasdk_dxtc ../apps/devid_cudasdk80/3_Imaging/dxtc
# dxtc
# ../apps/devid_cudasdk80/3_Imaging/dxtc/dxtc 732015
# shoc_lev1md5hash ../apps/devid_shoc/src/cuda/level1/md5hash
# MD5Hash
# ../apps/devid_shoc/src/cuda/level1/md5hash/MD5Hash 2190408
# parboil_bfs ../apps/devid_parboil/benchmarks/bfs
# bfs
# ../apps/devid_parboil/benchmarks/bfs/bfs 680795
# cudasdk_transpose ../apps/devid_cudasdk80/6_Advanced/transpose
# transpose
# ../apps/devid_cudasdk80/6_Advanced/transpose/transpose 684376
# shoc_lev1fft ../apps/devid_shoc/src/cuda/level1/fft
# FFT
# ../apps/devid_shoc/src/cuda/level1/fft/FFT 2480385
# rodinia_needle ../apps/devid_rodinia/nw
# needle
# ../apps/devid_rodinia/nw/needle 663738
# cudasdk_simpleCUBLAS ../apps/devid_cudasdk80/7_CUDALibraries/simpleCUBLAS
# simpleCUBLAS
# ../apps/devid_cudasdk80/7_CUDALibraries/simpleCUBLAS/simpleCUBLAS 574063
# rodinia_heartwall ../apps/devid_rodinia/heartwall
# heartwall
# ../apps/devid_rodinia/heartwall/heartwall 835783
# parboil_sgemm ../apps/devid_parboil/benchmarks/sgemm
# sgemm
# ../apps/devid_parboil/benchmarks/sgemm/sgemm 642547
# poly_3dconv ../apps/devid_poly/CUDA/3DCONV
# 3DConvolution.exe
# ../apps/devid_poly/CUDA/3DCONV/3DConvolution.exe 591623
# cudasdk_concurrentKernels ../apps/devid_cudasdk80/6_Advanced/concurrentKernels
# concurrentKernels
# ../apps/devid_cudasdk80/6_Advanced/concurrentKernels/concurrentKernels 608190
# cudasdk_fastWalshTransform ../apps/devid_cudasdk80/6_Advanced/fastWalshTransform
# fastWalshTransform
# ../apps/devid_cudasdk80/6_Advanced/fastWalshTransform/fastWalshTransform 639747
# cudasdk_SobolQRNG ../apps/devid_cudasdk80/4_Finance/SobolQRNG
# SobolQRNG
# ../apps/devid_cudasdk80/4_Finance/SobolQRNG/SobolQRNG 1440024
# poly_gesummv ../apps/devid_poly/CUDA/GESUMMV
# gesummv.exe
# ../apps/devid_poly/CUDA/GESUMMV/gesummv.exe 599819
# cudasdk_c++11Cuda ../apps/devid_cudasdk80/6_Advanced/c++11_cuda
# c++11_cuda
# ../apps/devid_cudasdk80/6_Advanced/c++11_cuda/c++11_cuda 1100247
# lonestar_bh ../apps/devid_lonestar/apps/bh
# bh
# ../apps/devid_lonestar/apps/bh/bh 728616
# cudasdk_FDTD3d ../apps/devid_cudasdk80/6_Advanced/FDTD3d
# FDTD3d
# ../apps/devid_cudasdk80/6_Advanced/FDTD3d/FDTD3d 684325
# shoc_lev1sort ../apps/devid_shoc/src/cuda/level1/sort
# Sort
# ../apps/devid_shoc/src/cuda/level1/sort/Sort 2023235
# cudasdk_radixSortThrust ../apps/devid_cudasdk80/6_Advanced/radixSortThrust
# radixSortThrust
# ../apps/devid_cudasdk80/6_Advanced/radixSortThrust/radixSortThrust 4466988
# parboil_stencil ../apps/devid_parboil/benchmarks/stencil
# stencil
# ../apps/devid_parboil/benchmarks/stencil/stencil 618363
# poly_correlation ../apps/devid_poly/CUDA/CORR
# correlation.exe
# ../apps/devid_poly/CUDA/CORR/correlation.exe 678270
# cudasdk_sortingNetworks ../apps/devid_cudasdk80/6_Advanced/sortingNetworks
# sortingNetworks
# ../apps/devid_cudasdk80/6_Advanced/sortingNetworks/sortingNetworks 776035
# cudasdk_convolutionSeparable ../apps/devid_cudasdk80/3_Imaging/convolutionSeparable
# convolutionSeparable
# ../apps/devid_cudasdk80/3_Imaging/convolutionSeparable/convolutionSeparable 668290
# poly_2dconv ../apps/devid_poly/CUDA/2DCONV
# 2DConvolution.exe
# ../apps/devid_poly/CUDA/2DCONV/2DConvolution.exe 591660
# cudasdk_batchCUBLAS ../apps/devid_cudasdk80/7_CUDALibraries/batchCUBLAS
# batchCUBLAS
# ../apps/devid_cudasdk80/7_CUDALibraries/batchCUBLAS/batchCUBLAS 598703
# rodinia_pathfinder ../apps/devid_rodinia/pathfinder
# pathfinder
# ../apps/devid_rodinia/pathfinder/pathfinder 595905
# parboil_mriq ../apps/devid_parboil/benchmarks/mri-q
# mri-q
# ../apps/devid_parboil/benchmarks/mri-q/mri-q 757189
# cudasdk_binomialOptions ../apps/devid_cudasdk80/4_Finance/binomialOptions
# binomialOptions
# ../apps/devid_cudasdk80/4_Finance/binomialOptions/binomialOptions 819949
# cudasdk_scalarProd ../apps/devid_cudasdk80/6_Advanced/scalarProd
# scalarProd
# ../apps/devid_cudasdk80/6_Advanced/scalarProd/scalarProd 618554
# cudasdk_MCEstimatePiQ ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiQ
# MC_EstimatePiQ
# ../apps/devid_cudasdk80/7_CUDALibraries/MC_EstimatePiQ/MC_EstimatePiQ 654631
# cudasdk_dwtHaar1D ../apps/devid_cudasdk80/3_Imaging/dwtHaar1D
# dwtHaar1D
# ../apps/devid_cudasdk80/3_Imaging/dwtHaar1D/dwtHaar1D 640666
# cudasdk_quasirandomGenerator ../apps/devid_cudasdk80/4_Finance/quasirandomGenerator
# quasirandomGenerator
# ../apps/devid_cudasdk80/4_Finance/quasirandomGenerator/quasirandomGenerator 656015
# cudasdk_reduction ../apps/devid_cudasdk80/6_Advanced/reduction
# reduction
# ../apps/devid_cudasdk80/6_Advanced/reduction/reduction 2328746
# cudasdk_simpleCUFFTcallback ../apps/devid_cudasdk80/7_CUDALibraries/simpleCUFFT_callback
# simpleCUFFT_callback
# ../apps/devid_cudasdk80/7_CUDALibraries/simpleCUFFT_callback/simpleCUFFT_callback 180649118
# cudasdk_segmentationTreeThrust ../apps/devid_cudasdk80/6_Advanced/segmentationTreeThrust
# segmentationTreeThrust
# ../apps/devid_cudasdk80/6_Advanced/segmentationTreeThrust/segmentationTreeThrust 12093727
# poly_fdtd2d ../apps/devid_poly/CUDA/FDTD-2D
# fdtd2d.exe
# ../apps/devid_poly/CUDA/FDTD-2D/fdtd2d.exe 612543
# poly_mvt ../apps/devid_poly/CUDA/MVT
# mvt.exe
# ../apps/devid_poly/CUDA/MVT/mvt.exe 616371
# lonestar_mst ../apps/devid_lonestar/apps/mst
# mst
# ../apps/devid_lonestar/apps/mst/mst 770871
# parboil_cutcp ../apps/devid_parboil/benchmarks/cutcp
# cutcp
# ../apps/devid_parboil/benchmarks/cutcp/cutcp 754339
# lonestar_sssp ../apps/devid_lonestar/apps/sssp
# sssp
# ../apps/devid_lonestar/apps/sssp/sssp 681279
# poly_3mm ../apps/devid_poly/CUDA/3MM
# 3mm.exe
# ../apps/devid_poly/CUDA/3MM/3mm.exe 628852
# cudasdk_convolutionTexture ../apps/devid_cudasdk80/3_Imaging/convolutionTexture
# convolutionTexture
# ../apps/devid_cudasdk80/3_Imaging/convolutionTexture/convolutionTexture 632314
# rodinia_gaussian ../apps/devid_rodinia/gaussian
# gaussian
# ../apps/devid_rodinia/gaussian/gaussian 612699
# cudasdk_matrixMul ../apps/devid_cudasdk80/0_Simple/matrixMul
# matrixMul
# ../apps/devid_cudasdk80/0_Simple/matrixMul/matrixMul 629328
# poly_bicg ../apps/devid_poly/CUDA/BICG
# bicg.exe
# ../apps/devid_poly/CUDA/BICG/bicg.exe 616378
# poly_syr2k ../apps/devid_poly/CUDA/SYR2K
# syr2k.exe
# ../apps/devid_poly/CUDA/SYR2K/syr2k.exe 595690
# cudasdk_eigenvalues ../apps/devid_cudasdk80/6_Advanced/eigenvalues
# eigenvalues
# ../apps/devid_cudasdk80/6_Advanced/eigenvalues/eigenvalues 930098
# poly_covariance ../apps/devid_poly/CUDA/COVAR
# covariance.exe
# ../apps/devid_poly/CUDA/COVAR/covariance.exe 637028
# cudasdk_scan ../apps/devid_cudasdk80/6_Advanced/scan
# scan
# ../apps/devid_cudasdk80/6_Advanced/scan/scan 635880
# cudasdk_MCSingleAsianOptionP ../apps/devid_cudasdk80/7_CUDALibraries/MC_SingleAsianOptionP
# MC_SingleAsianOptionP
# ../apps/devid_cudasdk80/7_CUDALibraries/MC_SingleAsianOptionP/MC_SingleAsianOptionP 1750537
# lonestar_dmr ../apps/devid_lonestar/apps/dmr
# dmr
# ../apps/devid_lonestar/apps/dmr/dmr 934863
# parboil_lbm ../apps/devid_parboil/benchmarks/lbm
# lbm
# ../apps/devid_parboil/benchmarks/lbm/lbm 639520
# rodinia_lud ../apps/devid_rodinia/lud
# cudasdk_dct8x8 ../apps/devid_cudasdk80/3_Imaging/dct8x8
# dct8x8
# ../apps/devid_cudasdk80/3_Imaging/dct8x8/dct8x8 821312
# cudasdk_interval ../apps/devid_cudasdk80/6_Advanced/interval
# interval
# ../apps/devid_cudasdk80/6_Advanced/interval/interval 855924
# cudasdk_mergeSort ../apps/devid_cudasdk80/6_Advanced/mergeSort
# mergeSort
# ../apps/devid_cudasdk80/6_Advanced/mergeSort/mergeSort 915252
# shoc_lev1reduction ../apps/devid_shoc/src/cuda/level1/reduction
# Reduction
# ../apps/devid_shoc/src/cuda/level1/reduction/Reduction 2028661
# cudasdk_stereoDisparity ../apps/devid_cudasdk80/3_Imaging/stereoDisparity
# stereoDisparity
# ../apps/devid_cudasdk80/3_Imaging/stereoDisparity/stereoDisparity 646437
# poly_atax ../apps/devid_poly/CUDA/ATAX
# atax.exe
# ../apps/devid_poly/CUDA/ATAX/atax.exe 616365
# cudasdk_boxFilterNPP ../apps/devid_cudasdk80/7_CUDALibraries/boxFilterNPP
# boxFilterNPP
# ../apps/devid_cudasdk80/7_CUDALibraries/boxFilterNPP/boxFilterNPP 4324283
# cudasdk_BlackScholes ../apps/devid_cudasdk80/4_Finance/BlackScholes
# BlackScholes
# ../apps/devid_cudasdk80/4_Finance/BlackScholes/BlackScholes 635283
# cudasdk_lineOfSight ../apps/devid_cudasdk80/6_Advanced/lineOfSight
# lineOfSight
# ../apps/devid_cudasdk80/6_Advanced/lineOfSight/lineOfSight 2447675
# poly_syrk ../apps/devid_poly/CUDA/SYRK
# syrk.exe
# ../apps/devid_poly/CUDA/SYRK/syrk.exe 599773
# rodinia_hotspot ../apps/devid_rodinia/hotspot
# hotspot
# ../apps/devid_rodinia/hotspot/hotspot 612364
# shoc_lev1GEMM ../apps/devid_shoc/src/cuda/level1/gemm
# GEMM
# ../apps/devid_shoc/src/cuda/level1/gemm/GEMM 2262813
# rodinia_backprop ../apps/devid_rodinia/backprop
# backprop
# ../apps/devid_rodinia/backprop/backprop 70908

# %%
for app, binsize in app_binsize_dd.iteritems():
    #print app, binsize
    print("{0: >30} {1:10d}".format(app, binsize))
# Out:
#                 rodinia_b+tree      90845
#              rodinia_heartwall     835783
#       cudasdk_convolutionFFT2D     720951
#                   shoc_lev1BFS    2557405
#                 rodinia_lavaMD      61578
#                      poly_gemm     595675
#             rodinia_hybridsort     763228
#    cudasdk_MCEstimatePiInlineQ    1487860
#    cudasdk_MCEstimatePiInlineP    1630233
#               cudasdk_shflscan     670816
#                  rodinia_dwt2d    1604815
#              cudasdk_vectorAdd     595510
#          cudasdk_MCEstimatePiP     654514
#        cudasdk_radixSortThrust    4466988
#               shoc_lev1md5hash    2190408
#                    parboil_bfs     680795
#                poly_covariance     637028
#                   shoc_lev1fft    2480385
# cudasdk_segmentationTreeThrust   12093727
#           cudasdk_simpleCUBLAS     574063
#                  parboil_sgemm     642547
#      cudasdk_concurrentKernels     608190
#     cudasdk_fastWalshTransform     639747
#              cudasdk_SobolQRNG    1440024
#                   poly_gesummv     599819
#              cudasdk_c++11Cuda    1100247
#                    lonestar_bh     728616
#                 cudasdk_FDTD3d     684325
#            cudasdk_eigenvalues     930098
#                   cudasdk_dxtc     732015
#                parboil_stencil     618363
#              cudasdk_reduction    2328746
#               poly_correlation     678270
#        cudasdk_sortingNetworks     776035
#   cudasdk_convolutionSeparable     668290
#                    poly_2dconv     591660
#            cudasdk_batchCUBLAS     598703
#             rodinia_pathfinder     595905
#                   parboil_mriq     757189
#        cudasdk_binomialOptions     819949
#             cudasdk_scalarProd     618554
#              cudasdk_dwtHaar1D     640666
#   cudasdk_quasirandomGenerator     656015
#   cudasdk_threadFenceReduction    1365373
#    cudasdk_simpleCUFFTcallback  180649118
#                 rodinia_needle     663738
#                    poly_fdtd2d     612543
#                       poly_mvt     616371
#                   lonestar_mst     770871
#                  parboil_cutcp     754339
#                  lonestar_sssp     681279
#                       poly_3mm     628852
#     cudasdk_convolutionTexture     632314
#               rodinia_gaussian     612699
#              cudasdk_matrixMul     629328
#                      poly_bicg     616378
#                     poly_syr2k     595690
#          cudasdk_MCEstimatePiQ     654631
#                  shoc_lev1sort    2023235
#                   cudasdk_scan     635880
#        cudasdk_stereoDisparity     646437
#   cudasdk_MCSingleAsianOptionP    1750537
#                   lonestar_dmr     934863
#                    parboil_lbm     639520
#                 cudasdk_dct8x8     821312
#               cudasdk_interval     855924
#              cudasdk_mergeSort     915252
#             shoc_lev1reduction    2028661
#              cudasdk_transpose     684376
#                      poly_atax     616365
#                    poly_3dconv     591623
#           cudasdk_BlackScholes     635283
#            cudasdk_lineOfSight    2447675
#                      poly_syrk     599773
#                rodinia_hotspot     612364
#           cudasdk_boxFilterNPP    4324283
#                  shoc_lev1GEMM    2262813
#               rodinia_backprop      70908

# %%
np.save('app_binsize_dd.npy', app_binsize_dd)
